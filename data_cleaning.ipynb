# %% [markdown]
# **Data Cleaning**
#
# Dirty data could include the following: missing values, duplicate values, and data in wrong format

# %%
import pandas as pd
import numpy as np

# %%
# importing the data
d = pd.read_csv("data_2.csv")

# %%
d.head()
# Out:
#    Duration           Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'     110       130     409.1
# 1        60   '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'     103       135     340.0
# 3        45   '2020/12/04'    109       175     282.4
# 4        45   '2020/12/05'    117       148     406.0

# %%
d
# Out:
#     Duration                Date  Pulse  Maxpulse  Calories
# 0         60       '2020/12/01'     110       130     409.1
# 1         60        '2020/12/02'    117       145     479.0
# 2         60       '2020/12/03'     103       135     340.0
# 3         45        '2020/12/04'    109       175     282.4
# 4         45        '2020/12/05'    117       148     406.0
# 5         60       '2020/12/06'     102       127     300.0
# 6         60        '2020/12/07'    110       136     374.0
# 7        450    '2020/12/08'        104       134     253.3
# 8         30    '2020/12/09'        109       133     195.1
# 9         60   '2020/12/10'          98       124     269.0
# 10        60    '2020/12/11'        103       147     329.3
# 11        60    '2020/12/12'        100       120     250.7
# 12        60    '2020/12/12'        100       120     250.7
# 13        60    '2020/12/13'        106       128     345.3
# 14        60    '2020/12/14'        104       132     379.3
# 15        60   '2020/12/15'          98       123     275.0
# 16        60   '2020/12/16'          98       120     215.2
# 17        60    '2020/12/17'        100       120     300.0
# 18        45   '2020/12/18'          90       112       NaN
# 19        60    '2020/12/19'        103       123     323.0
# 20        45   '2020/12/20'          97       125     243.0
# 21        60    '2020/12/21'        108       131     364.2
# 22        45                 NaN    100       119     282.0
# 23        60    '2020/12/23'        130       101     300.0
# 24        45    '2020/12/24'        105       132     246.0
# 25        60    '2020/12/25'        102       126     334.5
# 26        60            20201226    100       120     250.0
# 27        60   '2020/12/27'          92       118     241.0
# 28        60    '2020/12/28'        103       132       NaN
# 29        60    '2020/12/29'        100       132     280.0
# 30        60    '2020/12/30'        102       129     380.3
# 31        60   '2020/12/31'          92       115     243.0

# %%
d.shape
# Out:
# (32, 5)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
d.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
print(d.columns)
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
# checking for null values
d.isnull().any()
# Out:
# Duration    False
# Date         True
# Pulse       False
# Maxpulse    False
# Calories     True
# dtype: bool

# %%
# checking the number of null values
d.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
d["Date"].isnull().any()
# Out:
# np.True_

# %%
d["Date"].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# Name: Date, dtype: bool

# %%
d[d["Date"].isnull()]
# Out:
#     Duration Date  Pulse  Maxpulse  Calories
# 22        45  NaN    100       119     282.0

# %%
d["Calories"].isnull().any()
# Out:
# np.True_

# %%
d["Calories"].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# Name: Calories, dtype: bool

# %%
d[d["Calories"].isnull()]
# Out:
#     Duration                Date  Pulse  Maxpulse  Calories
# 18        45   '2020/12/18'          90       112       NaN
# 28        60    '2020/12/28'        103       132       NaN

# %%
# dropping null values (.reset_index())
data = d.dropna()

# %%
data
# Out:
#     Duration                Date  Pulse  Maxpulse  Calories
# 0         60       '2020/12/01'     110       130     409.1
# 1         60        '2020/12/02'    117       145     479.0
# 2         60       '2020/12/03'     103       135     340.0
# 3         45        '2020/12/04'    109       175     282.4
# 4         45        '2020/12/05'    117       148     406.0
# 5         60       '2020/12/06'     102       127     300.0
# 6         60        '2020/12/07'    110       136     374.0
# 7        450    '2020/12/08'        104       134     253.3
# 8         30    '2020/12/09'        109       133     195.1
# 9         60   '2020/12/10'          98       124     269.0
# 10        60    '2020/12/11'        103       147     329.3
# 11        60    '2020/12/12'        100       120     250.7
# 12        60    '2020/12/12'        100       120     250.7
# 13        60    '2020/12/13'        106       128     345.3
# 14        60    '2020/12/14'        104       132     379.3
# 15        60   '2020/12/15'          98       123     275.0
# 16        60   '2020/12/16'          98       120     215.2
# 17        60    '2020/12/17'        100       120     300.0
# 19        60    '2020/12/19'        103       123     323.0
# 20        45   '2020/12/20'          97       125     243.0
# 21        60    '2020/12/21'        108       131     364.2
# 23        60    '2020/12/23'        130       101     300.0
# 24        45    '2020/12/24'        105       132     246.0
# 25        60    '2020/12/25'        102       126     334.5
# 26        60            20201226    100       120     250.0
# 27        60   '2020/12/27'          92       118     241.0
# 29        60    '2020/12/29'        100       132     280.0
# 30        60    '2020/12/30'        102       129     380.3
# 31        60   '2020/12/31'          92       115     243.0

# %%
# d.fillna(10)  Not ideal, be specific with the column you want to fill it with

# %%
# d["Calories"].fillna(130)

# %%
# To replace with mean, median or mode

# %%
# d["Calories"].mean()

# %%
# d["Calories"].median()

# %%
# d["Calories"].mode() # returns all modes in a situation where there are multiple modes

# %%
# d["Calories"].mode() #returns the first mode from the list of all modes

# %%
# working on wront format
# To fix that, either delete the rows, or convert all cells in the column into the same format.

# %%
data.shape
# Out:
# (29, 5)

# %%
# To convert the date column to date
data["Date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 29 entries, 0 to 31
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 29 non-null     object
# dtypes: object(1)
# memory usage: 464.0+ bytes

# %%
data["Date"].head(10)
# Out:
# 0         '2020/12/01'
# 1          '2020/12/02'
# 2         '2020/12/03'
# 3          '2020/12/04'
# 4          '2020/12/05'
# 5         '2020/12/06'
# 6          '2020/12/07'
# 7      '2020/12/08'
# 8      '2020/12/09'
# 9     '2020/12/10'
# Name: Date, dtype: object

# %%
data["Date"] = data["Date"].str.replace("/", "-")
# Out:
# C:\Users\XANDER\AppData\Local\Temp\ipykernel_12776\2082816919.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Date"] = data["Date"].str.replace("/", "-")

# %%
data
# Out:
#     Duration                Date  Pulse  Maxpulse  Calories
# 0         60       '2020-12-01'     110       130     409.1
# 1         60        '2020-12-02'    117       145     479.0
# 2         60       '2020-12-03'     103       135     340.0
# 3         45        '2020-12-04'    109       175     282.4
# 4         45        '2020-12-05'    117       148     406.0
# 5         60       '2020-12-06'     102       127     300.0
# 6         60        '2020-12-07'    110       136     374.0
# 7        450    '2020-12-08'        104       134     253.3
# 8         30    '2020-12-09'        109       133     195.1
# 9         60   '2020-12-10'          98       124     269.0
# 10        60    '2020-12-11'        103       147     329.3
# 11        60    '2020-12-12'        100       120     250.7
# 12        60    '2020-12-12'        100       120     250.7
# 13        60    '2020-12-13'        106       128     345.3
# 14        60    '2020-12-14'        104       132     379.3
# 15        60   '2020-12-15'          98       123     275.0
# 16        60   '2020-12-16'          98       120     215.2
# 17        60    '2020-12-17'        100       120     300.0
# 19        60    '2020-12-19'        103       123     323.0
# 20        45   '2020-12-20'          97       125     243.0
# 21        60    '2020-12-21'        108       131     364.2
# 23        60    '2020-12-23'        130       101     300.0
# 24        45    '2020-12-24'        105       132     246.0
# 25        60    '2020-12-25'        102       126     334.5
# 26        60            20201226    100       120     250.0
# 27        60   '2020-12-27'          92       118     241.0
# 29        60    '2020-12-29'        100       132     280.0
# 30        60    '2020-12-30'        102       129     380.3
# 31        60   '2020-12-31'          92       115     243.0

# %%
data["Date"] = data["Date"].str.strip(" ")
# Out:
# C:\Users\XANDER\AppData\Local\Temp\ipykernel_12776\2403649539.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Date"] = data["Date"].str.strip(" ")

# %%
data["Date"] = data["Date"].str.replace("-", "")
# Out:
# C:\Users\XANDER\AppData\Local\Temp\ipykernel_12776\2043239679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Date"] = data["Date"].str.replace("-", "")

# %%
data
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  '20201201'    110       130     409.1
# 1         60  '20201202'    117       145     479.0
# 2         60  '20201203'    103       135     340.0
# 3         45  '20201204'    109       175     282.4
# 4         45  '20201205'    117       148     406.0
# 5         60  '20201206'    102       127     300.0
# 6         60  '20201207'    110       136     374.0
# 7        450  '20201208'    104       134     253.3
# 8         30  '20201209'    109       133     195.1
# 9         60  '20201210'     98       124     269.0
# 10        60  '20201211'    103       147     329.3
# 11        60  '20201212'    100       120     250.7
# 12        60  '20201212'    100       120     250.7
# 13        60  '20201213'    106       128     345.3
# 14        60  '20201214'    104       132     379.3
# 15        60  '20201215'     98       123     275.0
# 16        60  '20201216'     98       120     215.2
# 17        60  '20201217'    100       120     300.0
# 19        60  '20201219'    103       123     323.0
# 20        45  '20201220'     97       125     243.0
# 21        60  '20201221'    108       131     364.2
# 23        60  '20201223'    130       101     300.0
# 24        45  '20201224'    105       132     246.0
# 25        60  '20201225'    102       126     334.5
# 26        60    20201226    100       120     250.0
# 27        60  '20201227'     92       118     241.0
# 29        60  '20201229'    100       132     280.0
# 30        60  '20201230'    102       129     380.3
# 31        60  '20201231'     92       115     243.0

# %%
data["Date"].head(10)
# Out:
# 0    '20201201'
# 1    '20201202'
# 2    '20201203'
# 3    '20201204'
# 4    '20201205'
# 5    '20201206'
# 6    '20201207'
# 7    '20201208'
# 8    '20201209'
# 9    '20201210'
# Name: Date, dtype: object

# %%
data.loc[26].drop(columns = "Date", inplace = True)
# Out:
# C:\Users\XANDER\AppData\Local\Temp\ipykernel_12776\1866505338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[26].drop(columns = "Date", inplace = True)

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# 19        60 2020-12-19    103       123     323.0
# 20        45 2020-12-20     97       125     243.0
# 21        60 2020-12-21    108       131     364.2
# 23        60 2020-12-23    130       101     300.0
# 24        45 2020-12-24    105       132     246.0
# 25        60 2020-12-25    102       126     334.5
# 26        60 2020-12-26    100       120     250.0
# 27        60 2020-12-27     92       118     241.0
# 29        60 2020-12-29    100       132     280.0
# 30        60 2020-12-30    102       129     380.3
# 31        60 2020-12-31     92       115     243.0

# %%
data["Date"] = pd.to_datetime(data["Date"], format = "mixed")
# Out:
# C:\Users\XANDER\AppData\Local\Temp\ipykernel_12776\4232726897.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Date"] = pd.to_datetime(data["Date"], format = "mixed")

# %%
data["Date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 29 entries, 0 to 31
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 29 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 1.5 KB

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# 19        60 2020-12-19    103       123     323.0
# 20        45 2020-12-20     97       125     243.0
# 21        60 2020-12-21    108       131     364.2
# 23        60 2020-12-23    130       101     300.0
# 24        45 2020-12-24    105       132     246.0
# 25        60 2020-12-25    102       126     334.5
# 26        60 2020-12-26    100       120     250.0
# 27        60 2020-12-27     92       118     241.0
# 29        60 2020-12-29    100       132     280.0
# 30        60 2020-12-30    102       129     380.3
# 31        60 2020-12-31     92       115     243.0

# %%
# row 22 isn't a date thereby giving us NaT
# d.dropna(subset = ["Date"]) # to remove the row

# %%
# to insert the actual date on row 22 either by using "loc" or "at"to call out the index
# d.loc[22, "Date"] = pd.to_datetime(2020-12-22)

# %%
# to insert the actual date on row 22 either by using "loc" or "at"to call out the index
# d.at[22, "Date"] = pd.to_datetime(2020-12-22)

# %%
data.at[7, "Duration"] = 45

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# 19        60 2020-12-19    103       123     323.0
# 20        45 2020-12-20     97       125     243.0
# 21        60 2020-12-21    108       131     364.2
# 23        60 2020-12-23    130       101     300.0
# 24        45 2020-12-24    105       132     246.0
# 25        60 2020-12-25    102       126     334.5
# 26        60 2020-12-26    100       120     250.0
# 27        60 2020-12-27     92       118     241.0
# 29        60 2020-12-29    100       132     280.0
# 30        60 2020-12-30    102       129     380.3
# 31        60 2020-12-31     92       115     243.0

# %%
# Removing duplicates
data.duplicated().any()
# Out:
# np.True_

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data[data.duplicated()]
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 12        60 2020-12-12    100       120     250.7

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# 19        60 2020-12-19    103       123     323.0
# 20        45 2020-12-20     97       125     243.0
# 21        60 2020-12-21    108       131     364.2
# 23        60 2020-12-23    130       101     300.0
# 24        45 2020-12-24    105       132     246.0
# 25        60 2020-12-25    102       126     334.5
# 26        60 2020-12-26    100       120     250.0
# 27        60 2020-12-27     92       118     241.0
# 29        60 2020-12-29    100       132     280.0
# 30        60 2020-12-30    102       129     380.3
# 31        60 2020-12-31     92       115     243.0

# %%
# axis parameters
# axis = 0 index(rows) by default
# axis = 1 columns

# %%
data["dtion"] = data["Pulse"] + data["Maxpulse"]
# Out:
# C:\Users\XANDER\AppData\Local\Temp\ipykernel_12776\2047332808.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["dtion"] = data["Pulse"] + data["Maxpulse"]

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories  dtion
# 0         60 2020-12-01    110       130     409.1    240
# 1         60 2020-12-02    117       145     479.0    262
# 2         60 2020-12-03    103       135     340.0    238
# 3         45 2020-12-04    109       175     282.4    284
# 4         45 2020-12-05    117       148     406.0    265
# 5         60 2020-12-06    102       127     300.0    229
# 6         60 2020-12-07    110       136     374.0    246
# 7         45 2020-12-08    104       134     253.3    238
# 8         30 2020-12-09    109       133     195.1    242
# 9         60 2020-12-10     98       124     269.0    222
# 10        60 2020-12-11    103       147     329.3    250
# 11        60 2020-12-12    100       120     250.7    220
# 13        60 2020-12-13    106       128     345.3    234
# 14        60 2020-12-14    104       132     379.3    236
# 15        60 2020-12-15     98       123     275.0    221
# 16        60 2020-12-16     98       120     215.2    218
# 17        60 2020-12-17    100       120     300.0    220
# 19        60 2020-12-19    103       123     323.0    226
# 20        45 2020-12-20     97       125     243.0    222
# 21        60 2020-12-21    108       131     364.2    239
# 23        60 2020-12-23    130       101     300.0    231
# 24        45 2020-12-24    105       132     246.0    237
# 25        60 2020-12-25    102       126     334.5    228
# 26        60 2020-12-26    100       120     250.0    220
# 27        60 2020-12-27     92       118     241.0    210
# 29        60 2020-12-29    100       132     280.0    232
# 30        60 2020-12-30    102       129     380.3    231
# 31        60 2020-12-31     92       115     243.0    207

# %%
data = data.drop("dtion", axis = 1)

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# 19        60 2020-12-19    103       123     323.0
# 20        45 2020-12-20     97       125     243.0
# 21        60 2020-12-21    108       131     364.2
# 23        60 2020-12-23    130       101     300.0
# 24        45 2020-12-24    105       132     246.0
# 25        60 2020-12-25    102       126     334.5
# 26        60 2020-12-26    100       120     250.0
# 27        60 2020-12-27     92       118     241.0
# 29        60 2020-12-29    100       132     280.0
# 30        60 2020-12-30    102       129     380.3
# 31        60 2020-12-31     92       115     243.0

# %%
# the corr() method calculates the relations between each column in the dataset
# ignores non numeric column
data.corr()
# Out:
#           Duration      Date     Pulse  Maxpulse  Calories
# Duration  1.000000  0.217700 -0.183526 -0.391753  0.350969
# Date      0.217700  1.000000 -0.380088 -0.549973 -0.368101
# Pulse    -0.183526 -0.380088  1.000000  0.200177  0.503243
# Maxpulse -0.391753 -0.549973  0.200177  1.000000  0.338515
# Calories  0.350969 -0.368101  0.503243  0.338515  1.000000

# %%
# Visualization: You specify the chart you want with the "kind" argument
